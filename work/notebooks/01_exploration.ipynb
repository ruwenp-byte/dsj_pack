# %% [markdown]
# # 01 – Erste Datenexploration
# Lade Daten, inspiziere sie, visualisiere erste Zusammenhänge.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../sample_data.csv')
df.head()

# %%
df.describe()

# %%
sns.pairplot(df, hue='region'); plt.show()
